# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import random
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn import mixture
from lightgbm import LGBMClassifier

# %%
def feature_engineering(price, period, window):
    
    X = price.copy()
    mavg = X.rolling(period).mean()
    diff = X - mavg
    for i in range(window):
        X[str(i)] = diff.shift(i)  
    return X.dropna()

# %%
def labels(data, minimum, maximum):
    
    labels = []    
    for i in range(data.shape[0] - maximum):
        rand = random.randint(minimum, maximum)
        if data["Close"][i] <= (data["Close"][i + rand]):
            labels.append(0.0)
        else:
            data["Close"][i] >= data["Close"][i + rand]
            labels.append(1.0)
    data = data.iloc[:len(labels)].copy()
    data["y_hat"] = labels
    data = data.dropna()
    return data

# %%
def plot_pca(dataset):
    pca = PCA(n_components=0.9)
    components = pd.DataFrame(pca.fit_transform(dataset.iloc[:, 1:-1]))
    components["y_hat"] = dataset["y_hat"].reset_index(drop=True)
    sns.pairplot(data=components, hue="y_hat")
    plt.show();

# %%
df = pd.read_csv("data/ethusdt.csv", index_col="datetime")
df.head()
# Out:
#                       Close
# datetime
# 2020-01-01 00:00:00  128.91
# 2020-01-01 00:15:00  128.78
# 2020-01-01 00:30:00  128.86
# 2020-01-01 00:45:00  128.87
# 2020-01-01 01:00:00  129.13

# %%
df = feature_engineering(df, 10, 15)
df = labels(df, 5, 8)
df.head()
# Out:
#                       Close      0      1      2      3      4      5      6  \
# datetime
# 2020-01-01 05:45:00  130.30  0.048  0.040  0.071 -0.111 -0.166  0.028 -0.235
# 2020-01-01 06:00:00  130.48  0.192  0.048  0.040  0.071 -0.111 -0.166  0.028
# 2020-01-01 06:15:00  130.75  0.407  0.192  0.048  0.040  0.071 -0.111 -0.166
# 2020-01-01 06:30:00  130.62  0.237  0.407  0.192  0.048  0.040  0.071 -0.111
# 2020-01-01 06:45:00  130.44  0.032  0.237  0.407  0.192  0.048  0.040  0.071
#
#                          7      8      9     10     11     12     13     14  \
# datetime
# 2020-01-01 05:45:00 -0.250 -0.281 -0.367  0.092 -0.027  0.757  0.864  1.058
# 2020-01-01 06:00:00 -0.235 -0.250 -0.281 -0.367  0.092 -0.027  0.757  0.864
# 2020-01-01 06:15:00  0.028 -0.235 -0.250 -0.281 -0.367  0.092 -0.027  0.757
# 2020-01-01 06:30:00 -0.166  0.028 -0.235 -0.250 -0.281 -0.367  0.092 -0.027
# 2020-01-01 06:45:00 -0.111 -0.166  0.028 -0.235 -0.250 -0.281 -0.367  0.092
#
#                      y_hat
# datetime
# 2020-01-01 05:45:00    1.0
# 2020-01-01 06:00:00    1.0
# 2020-01-01 06:15:00    1.0
# 2020-01-01 06:30:00    1.0
# 2020-01-01 06:45:00    1.0

# %%
df2 = df.copy()
X = df2.iloc[:, 1:]
gmm = mixture.GaussianMixture(n_components=75)
gmm.fit(X)
# Out:
# C:\Users\Beauj\anaconda3\envs\quantitative_trading\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# GaussianMixture(n_components=75)

# %%
samples = gmm.sample(5000)
samples_df = pd.DataFrame(samples[0])
samples_df.rename(columns={samples_df.columns[-1]: "y_hat"},
                  inplace=True)
samples_df["y_hat"] = np.where(samples_df["y_hat"]>=0.5, 1, 0)
plot_pca(samples_df)

# %%
X = samples_df.iloc[:,:-1]
y = samples_df.iloc[:,-1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)
lgbm_clf = LGBMClassifier(n_estimators=1000,
                          max_depth=7)
lgbm_clf.fit(X_train,
             y_train,
             eval_set=(X_test, y_test),
             early_stopping_rounds=250)
# Out:
# [1]	valid_0's binary_logloss: 0.692864
# Training until validation scores don't improve for 250 rounds
# [2]	valid_0's binary_logloss: 0.693259
# [3]	valid_0's binary_logloss: 0.69379
# [4]	valid_0's binary_logloss: 0.694663
# [5]	valid_0's binary_logloss: 0.694745
# [6]	valid_0's binary_logloss: 0.695613
# [7]	valid_0's binary_logloss: 0.696191
# [8]	valid_0's binary_logloss: 0.696641
# [9]	valid_0's binary_logloss: 0.697349
# [10]	valid_0's binary_logloss: 0.697734
# [11]	valid_0's binary_logloss: 0.698151
# [12]	valid_0's binary_logloss: 0.698112
# [13]	valid_0's binary_logloss: 0.698449
# [14]	valid_0's binary_logloss: 0.698871
# [15]	valid_0's binary_logloss: 0.699779
# [16]	valid_0's binary_logloss: 0.698612
# [17]	valid_0's binary_logloss: 0.698539
# [18]	valid_0's binary_logloss: 0.699522
# [19]	valid_0's binary_logloss: 0.699297
# [20]	valid_0's binary_logloss: 0.699459
# [21]	valid_0's binary_logloss: 0.699866
# [22]	valid_0's binary_logloss: 0.69985
# [23]	valid_0's binary_logloss: 0.700543
# [24]	valid_0's binary_logloss: 0.70033
# [25]	valid_0's binary_logloss: 0.700457
# [26]	valid_0's binary_logloss: 0.701284
# [27]	valid_0's binary_logloss: 0.701389
# [28]	valid_0's binary_logloss: 0.701182
# [29]	valid_0's binary_logloss: 0.701665
# [30]	valid_0's binary_logloss: 0.701666
# [31]	valid_0's binary_logloss: 0.702255
# [32]	valid_0's binary_logloss: 0.702594
# [33]	valid_0's binary_logloss: 0.702081
# [34]	valid_0's binary_logloss: 0.702385
# [35]	valid_0's binary_logloss: 0.702253
# [36]	valid_0's binary_logloss: 0.702362
# [37]	valid_0's binary_logloss: 0.702232
# [38]	valid_0's binary_logloss: 0.702572
# [39]	valid_0's binary_logloss: 0.70229
# [40]	valid_0's binary_logloss: 0.702996
# [41]	valid_0's binary_logloss: 0.703506
# [42]	valid_0's binary_logloss: 0.703641
# [43]	valid_0's binary_logloss: 0.704009
# [44]	valid_0's binary_logloss: 0.703572
# [45]	valid_0's binary_logloss: 0.702994
# [46]	valid_0's binary_logloss: 0.702744
# [47]	valid_0's binary_logloss: 0.704019
# [48]	valid_0's binary_logloss: 0.70404
# [49]	valid_0's binary_logloss: 0.704097
# [50]	valid_0's binary_logloss: 0.704353
# [51]	valid_0's binary_logloss: 0.705096
# [52]	valid_0's binary_logloss: 0.705179
# [53]	valid_0's binary_logloss: 0.705328
# [54]	valid_0's binary_logloss: 0.705951
# [55]	valid_0's binary_logloss: 0.704962
# [56]	valid_0's binary_logloss: 0.705522
# [57]	valid_0's binary_logloss: 0.705308
# [58]	valid_0's binary_logloss: 0.704927
# [59]	valid_0's binary_logloss: 0.705457
# [60]	valid_0's binary_logloss: 0.706052
# [61]	valid_0's binary_logloss: 0.705983
# [62]	valid_0's binary_logloss: 0.705626
# [63]	valid_0's binary_logloss: 0.706269
# [64]	valid_0's binary_logloss: 0.706213
# [65]	valid_0's binary_logloss: 0.707083
# [66]	valid_0's binary_logloss: 0.707452
# [67]	valid_0's binary_logloss: 0.707396
# [68]	valid_0's binary_logloss: 0.708138
# [69]	valid_0's binary_logloss: 0.708463
# [70]	valid_0's binary_logloss: 0.708684
# [71]	valid_0's binary_logloss: 0.709581
# [72]	valid_0's binary_logloss: 0.709354
# [73]	valid_0's binary_logloss: 0.709436
# [74]	valid_0's binary_logloss: 0.70939
# [75]	valid_0's binary_logloss: 0.710037
# [76]	valid_0's binary_logloss: 0.710703
# [77]	valid_0's binary_logloss: 0.711948
# [78]	valid_0's binary_logloss: 0.711429
# [79]	valid_0's binary_logloss: 0.71182
# [80]	valid_0's binary_logloss: 0.712441
# [81]	valid_0's binary_logloss: 0.713677
# [82]	valid_0's binary_logloss: 0.714454
# [83]	valid_0's binary_logloss: 0.71433
# [84]	valid_0's binary_logloss: 0.715047
# [85]	valid_0's binary_logloss: 0.71489
# [86]	valid_0's binary_logloss: 0.715355
# [87]	valid_0's binary_logloss: 0.715693
# [88]	valid_0's binary_logloss: 0.716844
# [89]	valid_0's binary_logloss: 0.716419
# [90]	valid_0's binary_logloss: 0.716776
# [91]	valid_0's binary_logloss: 0.717904
# [92]	valid_0's binary_logloss: 0.718886
# [93]	valid_0's binary_logloss: 0.719774
# [94]	valid_0's binary_logloss: 0.720115
# [95]	valid_0's binary_logloss: 0.719751
# [96]	valid_0's binary_logloss: 0.72002
# [97]	valid_0's binary_logloss: 0.720234
# [98]	valid_0's binary_logloss: 0.720691
# [99]	valid_0's binary_logloss: 0.720731
# [100]	valid_0's binary_logloss: 0.720791
# [101]	valid_0's binary_logloss: 0.721635
# [102]	valid_0's binary_logloss: 0.722032
# [103]	valid_0's binary_logloss: 0.72307
# [104]	valid_0's binary_logloss: 0.723924
# [105]	valid_0's binary_logloss: 0.723587
# [106]	valid_0's binary_logloss: 0.725497
# [107]	valid_0's binary_logloss: 0.725628
# [108]	valid_0's binary_logloss: 0.725946
# [109]	valid_0's binary_logloss: 0.726537
# [110]	valid_0's binary_logloss: 0.726729
# [111]	valid_0's binary_logloss: 0.726554
# [112]	valid_0's binary_logloss: 0.726344
# [113]	valid_0's binary_logloss: 0.727107
# [114]	valid_0's binary_logloss: 0.726752
# [115]	valid_0's binary_logloss: 0.726805
# [116]	valid_0's binary_logloss: 0.726773
# [117]	valid_0's binary_logloss: 0.726268
# [118]	valid_0's binary_logloss: 0.726324
# [119]	valid_0's binary_logloss: 0.726553
# [120]	valid_0's binary_logloss: 0.727545
# [121]	valid_0's binary_logloss: 0.728438
# [122]	valid_0's binary_logloss: 0.729533
# [123]	valid_0's binary_logloss: 0.729501
# [124]	valid_0's binary_logloss: 0.729714
# [125]	valid_0's binary_logloss: 0.730017
# [126]	valid_0's binary_logloss: 0.731388
# [127]	valid_0's binary_logloss: 0.731862
# [128]	valid_0's binary_logloss: 0.733242
# [129]	valid_0's binary_logloss: 0.733277
# [130]	valid_0's binary_logloss: 0.733418
# [131]	valid_0's binary_logloss: 0.733858
# [132]	valid_0's binary_logloss: 0.733959
# [133]	valid_0's binary_logloss: 0.734124
# [134]	valid_0's binary_logloss: 0.734847
# [135]	valid_0's binary_logloss: 0.734851
# [136]	valid_0's binary_logloss: 0.735085
# [137]	valid_0's binary_logloss: 0.73656
# [138]	valid_0's binary_logloss: 0.736678
# [139]	valid_0's binary_logloss: 0.736897
# [140]	valid_0's binary_logloss: 0.737756
# [141]	valid_0's binary_logloss: 0.738112
# [142]	valid_0's binary_logloss: 0.738991
# [143]	valid_0's binary_logloss: 0.738968
# [144]	valid_0's binary_logloss: 0.739499
# [145]	valid_0's binary_logloss: 0.739781
# [146]	valid_0's binary_logloss: 0.740144
# [147]	valid_0's binary_logloss: 0.740929
# [148]	valid_0's binary_logloss: 0.741549
# [149]	valid_0's binary_logloss: 0.741417
# [150]	valid_0's binary_logloss: 0.741231
# [151]	valid_0's binary_logloss: 0.741741
# [152]	valid_0's binary_logloss: 0.742773
# [153]	valid_0's binary_logloss: 0.742502
# [154]	valid_0's binary_logloss: 0.742859
# [155]	valid_0's binary_logloss: 0.742831
# [156]	valid_0's binary_logloss: 0.743404
# [157]	valid_0's binary_logloss: 0.743509
# [158]	valid_0's binary_logloss: 0.743818
# [159]	valid_0's binary_logloss: 0.744935
# [160]	valid_0's binary_logloss: 0.744753
# [161]	valid_0's binary_logloss: 0.745419
# [162]	valid_0's binary_logloss: 0.745724
# [163]	valid_0's binary_logloss: 0.747171
# [164]	valid_0's binary_logloss: 0.748042
# [165]	valid_0's binary_logloss: 0.748768
# [166]	valid_0's binary_logloss: 0.749562
# [167]	valid_0's binary_logloss: 0.749868
# [168]	valid_0's binary_logloss: 0.750017
# [169]	valid_0's binary_logloss: 0.750457
# [170]	valid_0's binary_logloss: 0.750573
# [171]	valid_0's binary_logloss: 0.750879
# [172]	valid_0's binary_logloss: 0.75126
# [173]	valid_0's binary_logloss: 0.75149
# [174]	valid_0's binary_logloss: 0.751231
# [175]	valid_0's binary_logloss: 0.751298
# [176]	valid_0's binary_logloss: 0.751734
# [177]	valid_0's binary_logloss: 0.751705
# [178]	valid_0's binary_logloss: 0.751848
# [179]	valid_0's binary_logloss: 0.752362
# [180]	valid_0's binary_logloss: 0.752537
# [181]	valid_0's binary_logloss: 0.751689
# [182]	valid_0's binary_logloss: 0.75184
# [183]	valid_0's binary_logloss: 0.752459
# [184]	valid_0's binary_logloss: 0.753324
# [185]	valid_0's binary_logloss: 0.754425
# [186]	valid_0's binary_logloss: 0.75473
# [187]	valid_0's binary_logloss: 0.755904
# [188]	valid_0's binary_logloss: 0.755325
# [189]	valid_0's binary_logloss: 0.755797
# [190]	valid_0's binary_logloss: 0.756594
# [191]	valid_0's binary_logloss: 0.7572
# [192]	valid_0's binary_logloss: 0.756328
# [193]	valid_0's binary_logloss: 0.756989
# [194]	valid_0's binary_logloss: 0.758007
# [195]	valid_0's binary_logloss: 0.758838
# [196]	valid_0's binary_logloss: 0.759261
# [197]	valid_0's binary_logloss: 0.759968
# [198]	valid_0's binary_logloss: 0.759758
# [199]	valid_0's binary_logloss: 0.760852
# [200]	valid_0's binary_logloss: 0.760527
# [201]	valid_0's binary_logloss: 0.760645
# [202]	valid_0's binary_logloss: 0.761698
# [203]	valid_0's binary_logloss: 0.761878
# [204]	valid_0's binary_logloss: 0.761563
# [205]	valid_0's binary_logloss: 0.761252
# [206]	valid_0's binary_logloss: 0.761444
# [207]	valid_0's binary_logloss: 0.761951
# [208]	valid_0's binary_logloss: 0.762111
# [209]	valid_0's binary_logloss: 0.762288
# [210]	valid_0's binary_logloss: 0.762825
# [211]	valid_0's binary_logloss: 0.762927
# [212]	valid_0's binary_logloss: 0.763295
# [213]	valid_0's binary_logloss: 0.764111
# [214]	valid_0's binary_logloss: 0.764252
# [215]	valid_0's binary_logloss: 0.764277
# [216]	valid_0's binary_logloss: 0.764339
# [217]	valid_0's binary_logloss: 0.764679
# [218]	valid_0's binary_logloss: 0.76524
# [219]	valid_0's binary_logloss: 0.765548
# [220]	valid_0's binary_logloss: 0.765929
# [221]	valid_0's binary_logloss: 0.766945
# [222]	valid_0's binary_logloss: 0.766905
# [223]	valid_0's binary_logloss: 0.767783
# [224]	valid_0's binary_logloss: 0.768214
# [225]	valid_0's binary_logloss: 0.76809
# [226]	valid_0's binary_logloss: 0.769099
# [227]	valid_0's binary_logloss: 0.768676
# [228]	valid_0's binary_logloss: 0.769478
# [229]	valid_0's binary_logloss: 0.769077
# [230]	valid_0's binary_logloss: 0.768899
# [231]	valid_0's binary_logloss: 0.769292
# [232]	valid_0's binary_logloss: 0.768814
# [233]	valid_0's binary_logloss: 0.768529
# [234]	valid_0's binary_logloss: 0.768716
# [235]	valid_0's binary_logloss: 0.76925
# [236]	valid_0's binary_logloss: 0.769551
# [237]	valid_0's binary_logloss: 0.769439
# [238]	valid_0's binary_logloss: 0.769509
# [239]	valid_0's binary_logloss: 0.769892
# [240]	valid_0's binary_logloss: 0.769794
# [241]	valid_0's binary_logloss: 0.770071
# [242]	valid_0's binary_logloss: 0.770237
# [243]	valid_0's binary_logloss: 0.770293
# [244]	valid_0's binary_logloss: 0.770455
# [245]	valid_0's binary_logloss: 0.770379
# [246]	valid_0's binary_logloss: 0.770487
# [247]	valid_0's binary_logloss: 0.770599
# [248]	valid_0's binary_logloss: 0.770928
# [249]	valid_0's binary_logloss: 0.771191
# [250]	valid_0's binary_logloss: 0.77112
# [251]	valid_0's binary_logloss: 0.771741
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.692864
# LGBMClassifier(max_depth=7, n_estimators=1000)

# %%
lgbm_clf.score(X_test, y_test)
# Out:
# 0.524
